# %%
import json

# %%
with open("glints.json", "r") as file:
    data = json.load(file)
    print(json.dumps(data["data"]["searchJobs"]["jobsInPage"], indent=4))
# Out:
# [
#     {
#         "__typename": "Job",
#         "city": {
#             "__typename": "City",
#             "id": "28019",
#             "name": "Sidoarjo"
#         },
#         "citySubDivision": null,
#         "company": {
#             "IndustryId": 91,
#             "__typename": "Company",
#             "id": "c66b244a-6828-491d-8783-eb2d13f285b4",
#             "industry": {
#                 "__typename": "Industry",
#                 "id": 91,
#                 "name": "Consumer Services"
#             },
#             "isVIP": true,
#             "logo": "41c2be101e615b85f0aced4dd528c418.png",
#             "name": "PT Jago Rental",
#             "status": "VERIFIED",
#             "verificationTier": {
#                 "__typename": "verificationTier",
#                 "type": "LEGAL_DOCUMENTS"
#             }
#         },
#         "country": {
#             "__typename": "Country",
#             "code": "ID",
#             "name": "Indonesia"
#         },
#         "createdAt": "2025-03-18T08:17:52.460000Z",
#         "educationLevel": "HIGH_SCHOOL",
#         "fraudReportFlag": null,
#         "hierarchicalJobCategory": {
#             "__typename": "HierarchicalJobCategory",
#             "children": null,
#             "id": "43ea575e-f78b-4e77-ac83-27c26b47e2db",
#             "level": 3,
#             "name": "Mechanic",
#             "parents": [
#                 {
#                     "__typename": "JobCategoryChildAndParent",
#                     "id": "30fdbb6c-d16f-484d-8d45-a7eb1e4843a7",
#                     "level": 1,
#                     "name": "Manufacturing & Production"
#                 },
#                 {
#                     "__typename": "JobCategoryChildAndParent",
#                     "id": "63d3e438-1d3a-4c02-9bb2-c9ccafd94891",
#                     "level": 2,
#                     "name": "Car Manufacturer"
#                 }
#             ]
#         },
#         "id": "cf2852c3-6e33-44cc-ab07-5620adc31dab",
#         "isActivelyHiring": true,
#         "isApplied": false,
#         "isHot": true,
#         "location": {
#             "__typename": "HierarchicalLocation",
#             "administrativeLevelName": "District",
#             "formattedName": "Krian",
#             "id": "bacb3cd0-14bb-44a2-8d25-c67d6e45f8e9",
#             "latitude": -7.39972,
#             "level": 4,
#             "longitude": 112.59556,
#             "name": "Krian",
#             "parents": [
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "Kabupaten",
#                     "formattedName": "Kab. Sidoarjo",
#                     "id": "0c51be85-7a6e-4fe6-b802-4bbec5d5dcda",
#                     "level": 3,
#                     "name": "Sidoarjo",
#                     "parents": [
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Jawa Timur",
#                             "level": 2,
#                             "slug": "jawa-timur"
#                         },
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Indonesia",
#                             "level": 1,
#                             "slug": "indonesia"
#                         }
#                     ],
#                     "slug": "kab-sidoarjo"
#                 },
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "Province",
#                     "formattedName": "Jawa Timur",
#                     "id": "bc26ec98-d599-44cb-84e7-c92f6d87e102",
#                     "level": 2,
#                     "name": "Jawa Timur",
#                     "parents": [
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Indonesia",
#                             "level": 1,
#                             "slug": "indonesia"
#                         }
#                     ],
#                     "slug": "jawa-timur"
#                 },
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "Country",
#                     "formattedName": "Indonesia",
#                     "id": "7542a4d7-4324-4f76-ae1f-2e37ffb1198b",
#                     "level": 1,
#                     "name": "Indonesia",
#                     "parents": null,
#                     "slug": "indonesia"
#                 }
#             ],
#             "slug": "krian"
#         },
#         "maxYearsOfExperience": 10,
#         "minYearsOfExperience": 5,
#         "salaries": null,
#         "salaryEstimate": null,
#         "shouldShowSalary": false,
#         "skills": [
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "00134387-a3ed-4596-872b-d8af9eab8686",
#                     "name": "Mechanical"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "d75324b0-dc59-4064-9816-ec29a6455489",
#                     "name": "Troubleshooting"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "522f065d-7fcf-4ca7-b052-fcc3fbd2a74a",
#                     "name": "Mechanical Engineering"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "430e3cea-f330-494c-a76a-df8832e26016",
#                     "name": "Teamwork"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "275e958f-3ca5-4193-9960-70f779e2c1a4",
#                     "name": "Initiative"
#                 }
#             }
#         ],
#         "source": "NATIVE",
#         "status": "OPEN",
#         "title": "Mekanik Alat Berat",
#         "traceInfo": "a89141604fd6fe6e52b59a3d3b526f07",
#         "type": "FULL_TIME",
#         "updatedAt": "2025-03-18T08:39:59.486000Z",
#         "workArrangementOption": "ONSITE"
#     },
#     {
#         "__typename": "Job",
#         "city": {
#             "__typename": "City",
#             "id": "133413",
#             "name": "Jakarta Selatan"
#         },
#         "citySubDivision": {
#             "__typename": "CitySubDivision",
#             "id": "0xc000b2f000",
#             "name": "Kebayoran Lama"
#         },
#         "company": {
#             "IndustryId": 92,
#             "__typename": "Company",
#             "id": "a1541520-8c0b-4532-a763-fab14f51f714",
#             "industry": {
#                 "__typename": "Industry",
#                 "id": 92,
#                 "name": "Transportation/Trucking/Railroad"
#             },
#             "isVIP": true,
#             "logo": "6abd49804944e498603f62e69d78f957.jpg",
#             "name": "PT. BLUE BIRD TBK | POOL PALMERAH",
#             "status": "VERIFIED",
#             "verificationTier": {
#                 "__typename": "verificationTier",
#                 "type": "LEGAL_DOCUMENTS"
#             }
#         },
#         "country": {
#             "__typename": "Country",
#             "code": "ID",
#             "name": "Indonesia"
#         },
#         "createdAt": "2025-02-06T09:28:47.778000Z",
#         "educationLevel": "HIGH_SCHOOL",
#         "fraudReportFlag": null,
#         "hierarchicalJobCategory": {
#             "__typename": "HierarchicalJobCategory",
#             "children": null,
#             "id": "539e9d78-ddfe-4d7b-86fe-f6ee71f18945",
#             "level": 3,
#             "name": "Sales Operations",
#             "parents": [
#                 {
#                     "__typename": "JobCategoryChildAndParent",
#                     "id": "6202933c-ad93-45ac-86a9-b3e61042bc7c",
#                     "level": 1,
#                     "name": "Business Development & Sales"
#                 },
#                 {
#                     "__typename": "JobCategoryChildAndParent",
#                     "id": "2544f798-0522-4189-993c-1f2f03a7d684",
#                     "level": 2,
#                     "name": "Business Development"
#                 }
#             ]
#         },
#         "id": "2f83a569-c064-430e-b8f8-c75349a2e6e1",
#         "isActivelyHiring": true,
#         "isApplied": false,
#         "isHot": true,
#         "location": {
#             "__typename": "HierarchicalLocation",
#             "administrativeLevelName": "District",
#             "formattedName": "Kebayoran Lama",
#             "id": "c1892819-79bf-4f43-bdc6-4169cca33e84",
#             "latitude": -6.24861,
#             "level": 4,
#             "longitude": 106.77778,
#             "name": "Kebayoran Lama",
#             "parents": [
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "City",
#                     "formattedName": "Jakarta Selatan",
#                     "id": "078b37b2-e791-4739-958e-c29192e5df3e",
#                     "level": 3,
#                     "name": "Jakarta Selatan",
#                     "parents": [
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "DKI Jakarta",
#                             "level": 2,
#                             "slug": "dki-jakarta"
#                         },
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Indonesia",
#                             "level": 1,
#                             "slug": "indonesia"
#                         }
#                     ],
#                     "slug": "jakarta-selatan"
#                 },
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "Province",
#                     "formattedName": "DKI Jakarta",
#                     "id": "78d63064-78a1-4577-8516-036a6c5e903e",
#                     "level": 2,
#                     "name": "DKI Jakarta",
#                     "parents": [
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Indonesia",
#                             "level": 1,
#                             "slug": "indonesia"
#                         }
#                     ],
#                     "slug": "dki-jakarta"
#                 },
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "Country",
#                     "formattedName": "Indonesia",
#                     "id": "7542a4d7-4324-4f76-ae1f-2e37ffb1198b",
#                     "level": 1,
#                     "name": "Indonesia",
#                     "parents": null,
#                     "slug": "indonesia"
#                 }
#             ],
#             "slug": "kebayoran-lama"
#         },
#         "maxYearsOfExperience": 65,
#         "minYearsOfExperience": 0,
#         "salaries": [
#             {
#                 "CurrencyCode": "IDR",
#                 "__typename": "JobSalary",
#                 "id": "effaa7d7-4f96-419a-a5bb-bf682ee8ece3",
#                 "maxAmount": 7000000,
#                 "minAmount": 3000000,
#                 "salaryMode": "MONTH",
#                 "salaryType": "BASIC"
#             }
#         ],
#         "salaryEstimate": null,
#         "shouldShowSalary": true,
#         "skills": [
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "93e5ae52-65b4-4141-8fa1-299838b57aeb",
#                     "name": "Social Media Marketing & Management"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "ab03bd48-6934-46f5-a45f-6f52fed0b616",
#                     "name": "Sales Operations"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "65e37ba6-37f2-472a-bb8d-5f656e8b6737",
#                     "name": "Sales and Marketing"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "5569f78e-5537-47b5-90bd-6ca9c579ebeb",
#                     "name": "Sales Strategy"
#                 }
#             }
#         ],
#         "source": "NATIVE",
#         "status": "OPEN",
#         "title": "Sales Used Car",
#         "traceInfo": "a89141604fd6fe6e52b59a3d3b526f07",
#         "type": "FULL_TIME",
#         "updatedAt": "2025-03-18T08:36:11.163000Z",
#         "workArrangementOption": "HYBRID"
#     },
#     {
#         "__typename": "Job",
#         "city": {
#             "__typename": "City",
#             "id": "133420",
#             "name": "Jakarta Barat"
#         },
#         "citySubDivision": {
#             "__typename": "CitySubDivision",
#             "id": "0xc000b2f0d8",
#             "name": "Cengkareng"
#         },
#         "company": {
#             "IndustryId": 24,
#             "__typename": "Company",
#             "id": "255fe7cb-981f-43f0-8ce4-26915d4b5a63",
#             "industry": {
#                 "__typename": "Industry",
#                 "id": 24,
#                 "name": "Consumer Electronics"
#             },
#             "isVIP": true,
#             "logo": "4b57b53b83e0ea5b4e07363a7538adcf.png",
#             "name": "skmei smartwach",
#             "status": "VERIFIED",
#             "verificationTier": {
#                 "__typename": "verificationTier",
#                 "type": "LEGAL_DOCUMENTS"
#             }
#         },
#         "country": {
#             "__typename": "Country",
#             "code": "ID",
#             "name": "Indonesia"
#         },
#         "createdAt": "2025-03-10T07:16:00.194000Z",
#         "educationLevel": "DIPLOMA",
#         "fraudReportFlag": null,
#         "hierarchicalJobCategory": {
#             "__typename": "HierarchicalJobCategory",
#             "children": null,
#             "id": "84527699-17d9-48f2-83ff-f3805288e2f6",
#             "level": 3,
#             "name": "Chinese Translator",
#             "parents": [
#                 {
#                     "__typename": "JobCategoryChildAndParent",
#                     "id": "4270632e-15cc-4720-ba21-249fcb6a4a08",
#                     "level": 2,
#                     "name": "Translation"
#                 },
#                 {
#                     "__typename": "JobCategoryChildAndParent",
#                     "id": "3832902c-ff47-4efa-a173-3033962fcfc9",
#                     "level": 1,
#                     "name": "Legal, Consulting & Translation"
#                 }
#             ]
#         },
#         "id": "9b1fa2ef-0662-49ed-9981-19b962f82464",
#         "isActivelyHiring": true,
#         "isApplied": false,
#         "isHot": true,
#         "location": {
#             "__typename": "HierarchicalLocation",
#             "administrativeLevelName": "District",
#             "formattedName": "Cengkareng",
#             "id": "ea9cf55e-2236-402a-8861-d603d34d6624",
#             "latitude": -6.14722,
#             "level": 4,
#             "longitude": 106.7375,
#             "name": "Cengkareng",
#             "parents": [
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "City",
#                     "formattedName": "Jakarta Barat",
#                     "id": "af0ed74f-1b51-43cf-a14c-459996e39105",
#                     "level": 3,
#                     "name": "Jakarta Barat",
#                     "parents": [
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "DKI Jakarta",
#                             "level": 2,
#                             "slug": "dki-jakarta"
#                         },
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Indonesia",
#                             "level": 1,
#                             "slug": "indonesia"
#                         }
#                     ],
#                     "slug": "jakarta-barat"
#                 },
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "Province",
#                     "formattedName": "DKI Jakarta",
#                     "id": "78d63064-78a1-4577-8516-036a6c5e903e",
#                     "level": 2,
#                     "name": "DKI Jakarta",
#                     "parents": [
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Indonesia",
#                             "level": 1,
#                             "slug": "indonesia"
#                         }
#                     ],
#                     "slug": "dki-jakarta"
#                 },
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "Country",
#                     "formattedName": "Indonesia",
#                     "id": "7542a4d7-4324-4f76-ae1f-2e37ffb1198b",
#                     "level": 1,
#                     "name": "Indonesia",
#                     "parents": null,
#                     "slug": "indonesia"
#                 }
#             ],
#             "slug": "cengkareng"
#         },
#         "maxYearsOfExperience": 3,
#         "minYearsOfExperience": 1,
#         "salaries": [
#             {
#                 "CurrencyCode": "IDR",
#                 "__typename": "JobSalary",
#                 "id": "33be88c0-1e02-4ad0-a077-ff36d0211343",
#                 "maxAmount": 10000000,
#                 "minAmount": 6000000,
#                 "salaryMode": "MONTH",
#                 "salaryType": "BASIC"
#             }
#         ],
#         "salaryEstimate": null,
#         "shouldShowSalary": true,
#         "skills": [
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "430e3cea-f330-494c-a76a-df8832e26016",
#                     "name": "Teamwork"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "0fd2fe64-7472-4ef8-9675-dc15387a6ebd",
#                     "name": "Discipline"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "61016533-a45f-4486-a49a-a1d1b810ee43",
#                     "name": "Chinese-Indonesian Translation"
#                 }
#             }
#         ],
#         "source": "NATIVE",
#         "status": "OPEN",
#         "title": "Translator Profesional",
#         "traceInfo": "a89141604fd6fe6e52b59a3d3b526f07",
#         "type": "FULL_TIME",
#         "updatedAt": "2025-03-18T08:28:55.940000Z",
#         "workArrangementOption": "ONSITE"
#     },
#     {
#         "__typename": "Job",
#         "city": {
#             "__typename": "City",
#             "id": "29367",
#             "name": "Bandung"
#         },
#         "citySubDivision": null,
#         "company": {
#             "IndustryId": 116,
#             "__typename": "Company",
#             "id": "5d72e32f-335e-45c3-8452-db71d7135e6f",
#             "industry": {
#                 "__typename": "Industry",
#                 "id": 116,
#                 "name": "Logistics and Supply Chain"
#             },
#             "isVIP": true,
#             "logo": "305406cd0ac5223be6609227c3f9c199.jpg",
#             "name": "PT. Bambu Cemerlang Ekspres",
#             "status": "VERIFIED",
#             "verificationTier": {
#                 "__typename": "verificationTier",
#                 "type": "LEGAL_DOCUMENTS"
#             }
#         },
#         "country": {
#             "__typename": "Country",
#             "code": "ID",
#             "name": "Indonesia"
#         },
#         "createdAt": "2025-03-18T08:25:59.589000Z",
#         "educationLevel": "PRIMARY_SCHOOL",
#         "fraudReportFlag": null,
#         "hierarchicalJobCategory": {
#             "__typename": "HierarchicalJobCategory",
#             "children": null,
#             "id": "d7b7cfa4-12dc-4edd-8189-8a2bd5cb1bda",
#             "level": 3,
#             "name": "Courier",
#             "parents": [
#                 {
#                     "__typename": "JobCategoryChildAndParent",
#                     "id": "db71098c-8a00-44b5-bb4c-829e4c9bb869",
#                     "level": 1,
#                     "name": "Supply Chain, Logistics & Transportation"
#                 },
#                 {
#                     "__typename": "JobCategoryChildAndParent",
#                     "id": "8251d7f9-efd0-4356-ab81-0cd7463a8e54",
#                     "level": 2,
#                     "name": "Transportation"
#                 }
#             ]
#         },
#         "id": "36e931ec-79ca-4727-80d9-ce0374c7e983",
#         "isActivelyHiring": true,
#         "isApplied": false,
#         "isHot": true,
#         "location": {
#             "__typename": "HierarchicalLocation",
#             "administrativeLevelName": "District",
#             "formattedName": "Ranca Bali",
#             "id": "fa8fd169-3366-412b-9209-4c9bd2f4ce5f",
#             "latitude": -7.16889,
#             "level": 4,
#             "longitude": 107.35,
#             "name": "Ranca Bali",
#             "parents": [
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "Kabupaten",
#                     "formattedName": "Kab. Bandung",
#                     "id": "c11f7fd1-6982-4bc6-8eef-36ca4909b663",
#                     "level": 3,
#                     "name": "Bandung",
#                     "parents": [
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Jawa Barat",
#                             "level": 2,
#                             "slug": "jawa-barat"
#                         },
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Indonesia",
#                             "level": 1,
#                             "slug": "indonesia"
#                         }
#                     ],
#                     "slug": "kab-bandung"
#                 },
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "Province",
#                     "formattedName": "Jawa Barat",
#                     "id": "06c9e480-42e7-4f11-9d6c-67ad64ccc0f6",
#                     "level": 2,
#                     "name": "Jawa Barat",
#                     "parents": [
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Indonesia",
#                             "level": 1,
#                             "slug": "indonesia"
#                         }
#                     ],
#                     "slug": "jawa-barat"
#                 },
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "Country",
#                     "formattedName": "Indonesia",
#                     "id": "7542a4d7-4324-4f76-ae1f-2e37ffb1198b",
#                     "level": 1,
#                     "name": "Indonesia",
#                     "parents": null,
#                     "slug": "indonesia"
#                 }
#             ],
#             "slug": "ranca-bali"
#         },
#         "maxYearsOfExperience": 1,
#         "minYearsOfExperience": 0,
#         "salaries": [
#             {
#                 "CurrencyCode": "IDR",
#                 "__typename": "JobSalary",
#                 "id": "a400a835-4225-400f-a343-a745f9830560",
#                 "maxAmount": 4000000,
#                 "minAmount": 1000000,
#                 "salaryMode": "MONTH",
#                 "salaryType": "BASIC"
#             }
#         ],
#         "salaryEstimate": null,
#         "shouldShowSalary": true,
#         "skills": [
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "789d7445-e53c-47b3-ad96-f4accc023cbb",
#                     "name": "Driving"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "2a405491-c8a3-441c-8c01-17822c5bf937",
#                     "name": "Google Maps"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "f85329cd-213a-481a-b4f1-913c3682e4ad",
#                     "name": "Service Delivery"
#                 }
#             }
#         ],
#         "source": "NATIVE",
#         "status": "OPEN",
#         "title": "Kurir Motor area Rancabali - Pasirjambu - Katapang",
#         "traceInfo": "a89141604fd6fe6e52b59a3d3b526f07",
#         "type": "FULL_TIME",
#         "updatedAt": "2025-03-18T08:26:31.737000Z",
#         "workArrangementOption": "ONSITE"
#     },
#     {
#         "__typename": "Job",
#         "city": {
#             "__typename": "City",
#             "id": "133416",
#             "name": "Jakarta Utara"
#         },
#         "citySubDivision": {
#             "__typename": "CitySubDivision",
#             "id": "0xc000b2f288",
#             "name": "Penjaringan"
#         },
#         "company": {
#             "IndustryId": 27,
#             "__typename": "Company",
#             "id": "d3b0c576-67bf-48fe-8364-ddf511e37c29",
#             "industry": {
#                 "__typename": "Industry",
#                 "id": 27,
#                 "name": "Retail"
#             },
#             "isVIP": true,
#             "logo": "1994b3280c28e6a3994b42591854b1e1.png",
#             "name": "Bocorocco Shoes",
#             "status": "VERIFIED",
#             "verificationTier": {
#                 "__typename": "verificationTier",
#                 "type": "LEGAL_DOCUMENTS"
#             }
#         },
#         "country": {
#             "__typename": "Country",
#             "code": "ID",
#             "name": "Indonesia"
#         },
#         "createdAt": "2025-03-14T04:00:51.756000Z",
#         "educationLevel": "BACHELOR_DEGREE",
#         "fraudReportFlag": null,
#         "hierarchicalJobCategory": {
#             "__typename": "HierarchicalJobCategory",
#             "children": null,
#             "id": "6c0c3e28-260c-43a5-8194-729e5cee4277",
#             "level": 3,
#             "name": "Creative Executive",
#             "parents": [
#                 {
#                     "__typename": "JobCategoryChildAndParent",
#                     "id": "4dd15b5d-f06c-4b38-b941-94243721e831",
#                     "level": 2,
#                     "name": "Advertising & Public Relations"
#                 },
#                 {
#                     "__typename": "JobCategoryChildAndParent",
#                     "id": "f30ca820-580e-4e07-bf23-1f8fb96d6fc4",
#                     "level": 1,
#                     "name": "Marketing"
#                 }
#             ]
#         },
#         "id": "f6436c4e-572e-420f-afd5-58ff71e07145",
#         "isActivelyHiring": true,
#         "isApplied": false,
#         "isHot": true,
#         "location": {
#             "__typename": "HierarchicalLocation",
#             "administrativeLevelName": "District",
#             "formattedName": "Penjaringan",
#             "id": "037897c3-5ebb-4dbe-b7fb-a06521ea8e4f",
#             "latitude": -6.12083,
#             "level": 4,
#             "longitude": 106.76111,
#             "name": "Penjaringan",
#             "parents": [
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "City",
#                     "formattedName": "Jakarta Utara",
#                     "id": "ea61f4ac-5864-4b2b-a2c8-aa744a2aafea",
#                     "level": 3,
#                     "name": "Jakarta Utara",
#                     "parents": [
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "DKI Jakarta",
#                             "level": 2,
#                             "slug": "dki-jakarta"
#                         },
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Indonesia",
#                             "level": 1,
#                             "slug": "indonesia"
#                         }
#                     ],
#                     "slug": "jakarta-utara"
#                 },
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "Province",
#                     "formattedName": "DKI Jakarta",
#                     "id": "78d63064-78a1-4577-8516-036a6c5e903e",
#                     "level": 2,
#                     "name": "DKI Jakarta",
#                     "parents": [
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Indonesia",
#                             "level": 1,
#                             "slug": "indonesia"
#                         }
#                     ],
#                     "slug": "dki-jakarta"
#                 },
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "Country",
#                     "formattedName": "Indonesia",
#                     "id": "7542a4d7-4324-4f76-ae1f-2e37ffb1198b",
#                     "level": 1,
#                     "name": "Indonesia",
#                     "parents": null,
#                     "slug": "indonesia"
#                 }
#             ],
#             "slug": "penjaringan"
#         },
#         "maxYearsOfExperience": 1,
#         "minYearsOfExperience": 0,
#         "salaries": [
#             {
#                 "CurrencyCode": "IDR",
#                 "__typename": "JobSalary",
#                 "id": "39c2146b-516d-4a0b-8d6f-c68eb57b4770",
#                 "maxAmount": 3000000,
#                 "minAmount": 1500000,
#                 "salaryMode": "MONTH",
#                 "salaryType": "BASIC"
#             }
#         ],
#         "salaryEstimate": null,
#         "shouldShowSalary": true,
#         "skills": [
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "d678d75f-ed24-4653-8adf-6e794ae2e454",
#                     "name": "Adobe Premiere Pro"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "acf19883-3b70-4f77-b183-5747d9ba0fc9",
#                     "name": "CorelDRAW"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "f996d4e2-77f1-4998-89c3-cb6b9a4f2b7c",
#                     "name": "Adobe Photoshop"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "a2a48d66-716f-4b08-ae5f-4ba5a0fc66b9",
#                     "name": "Video Editing"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "7ec82e81-4feb-4a10-822e-6dac47f99c2d",
#                     "name": "Adobe Illustrator"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "802121bc-7806-4ce2-b25c-11a624ab61d5",
#                     "name": "Photo Editing"
#                 }
#             }
#         ],
#         "source": "NATIVE",
#         "status": "OPEN",
#         "title": "Creative Internship",
#         "traceInfo": "a89141604fd6fe6e52b59a3d3b526f07",
#         "type": "INTERNSHIP",
#         "updatedAt": "2025-03-18T08:07:44.897000Z",
#         "workArrangementOption": "ONSITE"
#     },
#     {
#         "__typename": "Job",
#         "city": {
#             "__typename": "City",
#             "id": "133419",
#             "name": "Jakarta Pusat"
#         },
#         "citySubDivision": {
#             "__typename": "CitySubDivision",
#             "id": "0xc000b2f390",
#             "name": "Gambir"
#         },
#         "company": {
#             "IndustryId": 55,
#             "__typename": "Company",
#             "id": "5027e7bc-9369-4fca-899c-9e1a3c67a50c",
#             "industry": {
#                 "__typename": "Industry",
#                 "id": 55,
#                 "name": "Machinery"
#             },
#             "isVIP": true,
#             "logo": "bfe008af702f62f856b414bc59bee9b5.jpg",
#             "name": "PND Ice Machine",
#             "status": "VERIFIED",
#             "verificationTier": {
#                 "__typename": "verificationTier",
#                 "type": "LEGAL_DOCUMENTS"
#             }
#         },
#         "country": {
#             "__typename": "Country",
#             "code": "ID",
#             "name": "Indonesia"
#         },
#         "createdAt": "2025-03-18T08:01:29.737000Z",
#         "educationLevel": "BACHELOR_DEGREE",
#         "fraudReportFlag": null,
#         "hierarchicalJobCategory": {
#             "__typename": "HierarchicalJobCategory",
#             "children": null,
#             "id": "ef980755-9ad3-4b9f-9599-80d786f4c246",
#             "level": 3,
#             "name": "Investor Relation Professional",
#             "parents": [
#                 {
#                     "__typename": "JobCategoryChildAndParent",
#                     "id": "537763fb-c2e6-4077-aa34-f42fc906d075",
#                     "level": 2,
#                     "name": "Accounting"
#                 },
#                 {
#                     "__typename": "JobCategoryChildAndParent",
#                     "id": "f1efc1a5-79e7-48e2-8adc-50dd141fe6e9",
#                     "level": 1,
#                     "name": "Administrative & HR & Accounting"
#                 }
#             ]
#         },
#         "id": "0df03be3-f073-4057-887d-9aec36c13e11",
#         "isActivelyHiring": true,
#         "isApplied": false,
#         "isHot": true,
#         "location": {
#             "__typename": "HierarchicalLocation",
#             "administrativeLevelName": "District",
#             "formattedName": "Gambir",
#             "id": "c3754bdf-fa78-428f-ae5a-ccb5fe31fdec",
#             "latitude": -6.17083,
#             "level": 4,
#             "longitude": 106.81806,
#             "name": "Gambir",
#             "parents": [
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "City",
#                     "formattedName": "Jakarta Pusat",
#                     "id": "e2a615bb-0997-42c8-a018-c4a1768ae01f",
#                     "level": 3,
#                     "name": "Jakarta Pusat",
#                     "parents": [
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "DKI Jakarta",
#                             "level": 2,
#                             "slug": "dki-jakarta"
#                         },
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Indonesia",
#                             "level": 1,
#                             "slug": "indonesia"
#                         }
#                     ],
#                     "slug": "jakarta-pusat"
#                 },
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "Province",
#                     "formattedName": "DKI Jakarta",
#                     "id": "78d63064-78a1-4577-8516-036a6c5e903e",
#                     "level": 2,
#                     "name": "DKI Jakarta",
#                     "parents": [
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Indonesia",
#                             "level": 1,
#                             "slug": "indonesia"
#                         }
#                     ],
#                     "slug": "dki-jakarta"
#                 },
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "Country",
#                     "formattedName": "Indonesia",
#                     "id": "7542a4d7-4324-4f76-ae1f-2e37ffb1198b",
#                     "level": 1,
#                     "name": "Indonesia",
#                     "parents": null,
#                     "slug": "indonesia"
#                 }
#             ],
#             "slug": "gambir"
#         },
#         "maxYearsOfExperience": 5,
#         "minYearsOfExperience": 3,
#         "salaries": null,
#         "salaryEstimate": null,
#         "shouldShowSalary": false,
#         "skills": [
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "7b653f7a-bedd-4aea-bf1c-15a08f2ab5ec",
#                     "name": "Communication Skills"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "85074f06-9940-4eb7-ad98-3342c7924013",
#                     "name": "Negotiation Skills"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "4cf77753-f2a1-40f6-a2ef-5bbb35cff413",
#                     "name": "Team Leadership"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "79fd1ab7-4ba8-44fa-9ad7-6dc0f4afb892",
#                     "name": "Investment Analysis"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "8042b538-40f9-44cd-a5d4-e0cad4e9066e",
#                     "name": "Relationship Management"
#                 }
#             }
#         ],
#         "source": "NATIVE",
#         "status": "OPEN",
#         "title": "CEO Office",
#         "traceInfo": "a89141604fd6fe6e52b59a3d3b526f07",
#         "type": "FULL_TIME",
#         "updatedAt": "2025-03-18T08:01:42.434000Z",
#         "workArrangementOption": "HYBRID"
#     },
#     {
#         "__typename": "Job",
#         "city": {
#             "__typename": "City",
#             "id": "28570",
#             "name": "Malang"
#         },
#         "citySubDivision": null,
#         "company": {
#             "IndustryId": 30,
#             "__typename": "Company",
#             "id": "4703f7d9-c1c4-4e4a-b086-59ca55c6977d",
#             "industry": {
#                 "__typename": "Industry",
#                 "id": 30,
#                 "name": "Leisure, Travel & Tourism"
#             },
#             "isVIP": true,
#             "logo": "5fdec5b790d376a5405f7fab3e6a9281.png",
#             "name": "PT Persada Duta Beliton (Persada Indonesia Brand)",
#             "status": "VERIFIED",
#             "verificationTier": {
#                 "__typename": "verificationTier",
#                 "type": "LEGAL_DOCUMENTS"
#             }
#         },
#         "country": {
#             "__typename": "Country",
#             "code": "ID",
#             "name": "Indonesia"
#         },
#         "createdAt": "2025-02-18T03:25:46.354000Z",
#         "educationLevel": "BACHELOR_DEGREE",
#         "fraudReportFlag": null,
#         "hierarchicalJobCategory": {
#             "__typename": "HierarchicalJobCategory",
#             "children": null,
#             "id": "27ca0103-0a1b-48d2-8ab0-f37180ad4891",
#             "level": 3,
#             "name": "Sales Executive",
#             "parents": [
#                 {
#                     "__typename": "JobCategoryChildAndParent",
#                     "id": "6202933c-ad93-45ac-86a9-b3e61042bc7c",
#                     "level": 1,
#                     "name": "Business Development & Sales"
#                 },
#                 {
#                     "__typename": "JobCategoryChildAndParent",
#                     "id": "6aa6ef6a-95ea-4046-ae0d-6c424d48fc54",
#                     "level": 2,
#                     "name": "Sales"
#                 }
#             ]
#         },
#         "id": "f6eeb8e3-97d0-44a9-9223-c08bc6b5d4a8",
#         "isActivelyHiring": true,
#         "isApplied": false,
#         "isHot": true,
#         "location": {
#             "__typename": "HierarchicalLocation",
#             "administrativeLevelName": "District",
#             "formattedName": "Lowokwaru",
#             "id": "89f8541a-4c09-44f0-a1ec-b3dfcb19b20d",
#             "latitude": -7.93611,
#             "level": 4,
#             "longitude": 112.61806,
#             "name": "Lowokwaru",
#             "parents": [
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "City",
#                     "formattedName": "Malang",
#                     "id": "6ec28332-761a-4ee9-b0d8-52171a170edf",
#                     "level": 3,
#                     "name": "Malang",
#                     "parents": [
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Jawa Timur",
#                             "level": 2,
#                             "slug": "jawa-timur"
#                         },
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Indonesia",
#                             "level": 1,
#                             "slug": "indonesia"
#                         }
#                     ],
#                     "slug": "malang"
#                 },
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "Province",
#                     "formattedName": "Jawa Timur",
#                     "id": "bc26ec98-d599-44cb-84e7-c92f6d87e102",
#                     "level": 2,
#                     "name": "Jawa Timur",
#                     "parents": [
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Indonesia",
#                             "level": 1,
#                             "slug": "indonesia"
#                         }
#                     ],
#                     "slug": "jawa-timur"
#                 },
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "Country",
#                     "formattedName": "Indonesia",
#                     "id": "7542a4d7-4324-4f76-ae1f-2e37ffb1198b",
#                     "level": 1,
#                     "name": "Indonesia",
#                     "parents": null,
#                     "slug": "indonesia"
#                 }
#             ],
#             "slug": "lowokwaru"
#         },
#         "maxYearsOfExperience": 1,
#         "minYearsOfExperience": 0,
#         "salaries": null,
#         "salaryEstimate": null,
#         "shouldShowSalary": false,
#         "skills": [
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "430e3cea-f330-494c-a76a-df8832e26016",
#                     "name": "Teamwork"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "65e37ba6-37f2-472a-bb8d-5f656e8b6737",
#                     "name": "Sales and Marketing"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "7b653f7a-bedd-4aea-bf1c-15a08f2ab5ec",
#                     "name": "Communication Skills"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "85074f06-9940-4eb7-ad98-3342c7924013",
#                     "name": "Negotiation Skills"
#                 }
#             }
#         ],
#         "source": "NATIVE",
#         "status": "OPEN",
#         "title": "Sales Executive (Cabang Malang & Gresik)",
#         "traceInfo": "a89141604fd6fe6e52b59a3d3b526f07",
#         "type": "FULL_TIME",
#         "updatedAt": "2025-03-18T08:00:41.332000Z",
#         "workArrangementOption": "ONSITE"
#     },
#     {
#         "__typename": "Job",
#         "city": {
#             "__typename": "City",
#             "id": "133420",
#             "name": "Jakarta Barat"
#         },
#         "citySubDivision": {
#             "__typename": "CitySubDivision",
#             "id": "0xc000b2f778",
#             "name": "Grogol Petamburan"
#         },
#         "company": {
#             "IndustryId": 27,
#             "__typename": "Company",
#             "id": "209f29d1-24c3-446a-a2c9-4c141e993b44",
#             "industry": {
#                 "__typename": "Industry",
#                 "id": 27,
#                 "name": "Retail"
#             },
#             "isVIP": true,
#             "logo": "b4b6d4378e7834800bf5395c8685ce8d.jpg",
#             "name": "Nusantara Sakti Group",
#             "status": "VERIFIED",
#             "verificationTier": {
#                 "__typename": "verificationTier",
#                 "type": "LEGAL_DOCUMENTS"
#             }
#         },
#         "country": {
#             "__typename": "Country",
#             "code": "ID",
#             "name": "Indonesia"
#         },
#         "createdAt": "2025-03-15T04:58:53.623000Z",
# ...
#                     "parents": [
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "DKI Jakarta",
#                             "level": 2,
#                             "slug": "dki-jakarta"
#                         },
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Indonesia",
#                             "level": 1,
#                             "slug": "indonesia"
#                         }
#                     ],
#                     "slug": "jakarta-barat"
#                 },
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "Province",
#                     "formattedName": "DKI Jakarta",
#                     "id": "78d63064-78a1-4577-8516-036a6c5e903e",
#                     "level": 2,
#                     "name": "DKI Jakarta",
#                     "parents": [
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Indonesia",
#                             "level": 1,
#                             "slug": "indonesia"
#                         }
#                     ],
#                     "slug": "dki-jakarta"
#                 },
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "Country",
#                     "formattedName": "Indonesia",
#                     "id": "7542a4d7-4324-4f76-ae1f-2e37ffb1198b",
#                     "level": 1,
#                     "name": "Indonesia",
#                     "parents": null,
#                     "slug": "indonesia"
#                 }
#             ],
#             "slug": "cengkareng"
#         },
#         "maxYearsOfExperience": 3,
#         "minYearsOfExperience": 1,
#         "salaries": [
#             {
#                 "CurrencyCode": "IDR",
#                 "__typename": "JobSalary",
#                 "id": "7013f613-4330-492f-b539-50d954ba0243",
#                 "maxAmount": 5500000,
#                 "minAmount": 5000000,
#                 "salaryMode": "MONTH",
#                 "salaryType": "BASIC"
#             }
#         ],
#         "salaryEstimate": null,
#         "shouldShowSalary": true,
#         "skills": [
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "80f61992-6fea-448d-877e-8939f342d66c",
#                     "name": "Public Speaking"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "430e3cea-f330-494c-a76a-df8832e26016",
#                     "name": "Teamwork"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "7b653f7a-bedd-4aea-bf1c-15a08f2ab5ec",
#                     "name": "Communication Skills"
#                 }
#             }
#         ],
#         "source": "NATIVE",
#         "status": "OPEN",
#         "title": "Host Live Streaming",
#         "traceInfo": "a89141604fd6fe6e52b59a3d3b526f07",
#         "type": "FULL_TIME",
#         "updatedAt": "2025-03-18T02:29:44.841000Z",
#         "workArrangementOption": "ONSITE"
#     },
#     {
#         "__typename": "Job",
#         "city": {
#             "__typename": "City",
#             "id": "29110",
#             "name": "Cimahi"
#         },
#         "citySubDivision": null,
#         "company": {
#             "IndustryId": 60,
#             "__typename": "Company",
#             "id": "373d0a23-4b10-4236-81c8-0c3ed51c8016",
#             "industry": {
#                 "__typename": "Industry",
#                 "id": 60,
#                 "name": "Textiles"
#             },
#             "isVIP": true,
#             "logo": "a1a721437eb6532b6b0b53371ac0efb8.jpg",
#             "name": "PT Sinar Continental",
#             "status": "VERIFIED",
#             "verificationTier": {
#                 "__typename": "verificationTier",
#                 "type": "LEGAL_DOCUMENTS"
#             }
#         },
#         "country": {
#             "__typename": "Country",
#             "code": "ID",
#             "name": "Indonesia"
#         },
#         "createdAt": "2024-04-05T08:24:27.082000Z",
#         "educationLevel": "BACHELOR_DEGREE",
#         "fraudReportFlag": null,
#         "hierarchicalJobCategory": {
#             "__typename": "HierarchicalJobCategory",
#             "children": null,
#             "id": "e602d9fb-8a70-4ba7-916d-d0e49c6c5516",
#             "level": 3,
#             "name": "Accountant",
#             "parents": [
#                 {
#                     "__typename": "JobCategoryChildAndParent",
#                     "id": "537763fb-c2e6-4077-aa34-f42fc906d075",
#                     "level": 2,
#                     "name": "Accounting"
#                 },
#                 {
#                     "__typename": "JobCategoryChildAndParent",
#                     "id": "f1efc1a5-79e7-48e2-8adc-50dd141fe6e9",
#                     "level": 1,
#                     "name": "Administrative & HR & Accounting"
#                 }
#             ]
#         },
#         "id": "7c37936f-b275-4069-8a9a-20a0257e1cb9",
#         "isActivelyHiring": true,
#         "isApplied": false,
#         "isHot": true,
#         "location": {
#             "__typename": "HierarchicalLocation",
#             "administrativeLevelName": "District",
#             "formattedName": "Cimahi Selatan",
#             "id": "f3315c37-0a35-42c1-aa31-fc57487e4f78",
#             "latitude": -6.90806,
#             "level": 4,
#             "longitude": 107.54,
#             "name": "Cimahi Selatan",
#             "parents": [
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "City",
#                     "formattedName": "Cimahi",
#                     "id": "89637124-13ea-4bd5-8e4d-1d9dfe41e37d",
#                     "level": 3,
#                     "name": "Cimahi",
#                     "parents": [
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Jawa Barat",
#                             "level": 2,
#                             "slug": "jawa-barat"
#                         },
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Indonesia",
#                             "level": 1,
#                             "slug": "indonesia"
#                         }
#                     ],
#                     "slug": "cimahi"
#                 },
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "Province",
#                     "formattedName": "Jawa Barat",
#                     "id": "06c9e480-42e7-4f11-9d6c-67ad64ccc0f6",
#                     "level": 2,
#                     "name": "Jawa Barat",
#                     "parents": [
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Indonesia",
#                             "level": 1,
#                             "slug": "indonesia"
#                         }
#                     ],
#                     "slug": "jawa-barat"
#                 },
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "Country",
#                     "formattedName": "Indonesia",
#                     "id": "7542a4d7-4324-4f76-ae1f-2e37ffb1198b",
#                     "level": 1,
#                     "name": "Indonesia",
#                     "parents": null,
#                     "slug": "indonesia"
#                 }
#             ],
#             "slug": "cimahi-selatan"
#         },
#         "maxYearsOfExperience": 1,
#         "minYearsOfExperience": 0,
#         "salaries": null,
#         "salaryEstimate": null,
#         "shouldShowSalary": false,
#         "skills": [
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "b40ba574-80b9-40e1-8df4-ac6739543fd1",
#                     "name": "Microsoft Office"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "430e3cea-f330-494c-a76a-df8832e26016",
#                     "name": "Teamwork"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "48fba095-03ee-4720-a5ef-27956668ed54",
#                     "name": "Microsoft Excel"
#                 }
#             }
#         ],
#         "source": "NATIVE",
#         "status": "OPEN",
#         "title": "Staff Accounting & Finance",
#         "traceInfo": "a89141604fd6fe6e52b59a3d3b526f07",
#         "type": "FULL_TIME",
#         "updatedAt": "2025-03-18T01:58:35.613000Z",
#         "workArrangementOption": "ONSITE"
#     },
#     {
#         "__typename": "Job",
#         "city": {
#             "__typename": "City",
#             "id": "27918",
#             "name": "Surabaya"
#         },
#         "citySubDivision": null,
#         "company": {
#             "IndustryId": 23,
#             "__typename": "Company",
#             "id": "b2035284-2374-4544-b243-6f9ab57ec8e7",
#             "industry": {
#                 "__typename": "Industry",
#                 "id": 23,
#                 "name": "Food Production"
#             },
#             "isVIP": true,
#             "logo": "7a6d46e0b22abcc8d2e81cab481ea59f.png",
#             "name": "Manna Indo Lakta (MamaBear)",
#             "status": "VERIFIED",
#             "verificationTier": {
#                 "__typename": "verificationTier",
#                 "type": "LEGAL_DOCUMENTS"
#             }
#         },
#         "country": {
#             "__typename": "Country",
#             "code": "ID",
#             "name": "Indonesia"
#         },
#         "createdAt": "2025-02-25T03:54:39.546000Z",
#         "educationLevel": "BACHELOR_DEGREE",
#         "fraudReportFlag": null,
#         "hierarchicalJobCategory": {
#             "__typename": "HierarchicalJobCategory",
#             "children": null,
#             "id": "8d9df1b8-abfc-40b3-95ab-a2a2ac3edba9",
#             "level": 3,
#             "name": "Pharmacist",
#             "parents": [
#                 {
#                     "__typename": "JobCategoryChildAndParent",
#                     "id": "57c9eabe-88ab-4eff-87be-92a44bc8f1dd",
#                     "level": 1,
#                     "name": "Healthcare"
#                 },
#                 {
#                     "__typename": "JobCategoryChildAndParent",
#                     "id": "3417b066-2368-40d2-aa99-e0e8daefb362",
#                     "level": 2,
#                     "name": "Pharmacy"
#                 }
#             ]
#         },
#         "id": "16d8c1cd-3351-4ea5-933a-fc55e484ab53",
#         "isActivelyHiring": true,
#         "isApplied": false,
#         "isHot": true,
#         "location": {
#             "__typename": "HierarchicalLocation",
#             "administrativeLevelName": "District",
#             "formattedName": "Sambikerep",
#             "id": "1cfe978d-e978-4e6d-ac00-78b60c927372",
#             "latitude": -7.27667,
#             "level": 4,
#             "longitude": 112.65306,
#             "name": "Sambikerep",
#             "parents": [
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "City",
#                     "formattedName": "Surabaya",
#                     "id": "0822446a-8784-4af4-bc88-9f9294fca382",
#                     "level": 3,
#                     "name": "Surabaya",
#                     "parents": [
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Jawa Timur",
#                             "level": 2,
#                             "slug": "jawa-timur"
#                         },
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Indonesia",
#                             "level": 1,
#                             "slug": "indonesia"
#                         }
#                     ],
#                     "slug": "surabaya"
#                 },
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "Province",
#                     "formattedName": "Jawa Timur",
#                     "id": "bc26ec98-d599-44cb-84e7-c92f6d87e102",
#                     "level": 2,
#                     "name": "Jawa Timur",
#                     "parents": [
#                         {
#                             "__typename": "LocationGrandParent",
#                             "formattedName": "Indonesia",
#                             "level": 1,
#                             "slug": "indonesia"
#                         }
#                     ],
#                     "slug": "jawa-timur"
#                 },
#                 {
#                     "CountryCode": "ID",
#                     "__typename": "LocationParent",
#                     "administrativeLevelName": "Country",
#                     "formattedName": "Indonesia",
#                     "id": "7542a4d7-4324-4f76-ae1f-2e37ffb1198b",
#                     "level": 1,
#                     "name": "Indonesia",
#                     "parents": null,
#                     "slug": "indonesia"
#                 }
#             ],
#             "slug": "sambikerep"
#         },
#         "maxYearsOfExperience": 3,
#         "minYearsOfExperience": 1,
#         "salaries": [
#             {
#                 "CurrencyCode": "IDR",
#                 "__typename": "JobSalary",
#                 "id": "ba07cfb7-9253-4ad1-9e2c-1b4cd34a15f6",
#                 "maxAmount": 7000000,
#                 "minAmount": 5000000,
#                 "salaryMode": "MONTH",
#                 "salaryType": "BASIC"
#             }
#         ],
#         "salaryEstimate": null,
#         "shouldShowSalary": true,
#         "skills": [
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "a345206f-9190-48da-9b1c-14a21196d41e",
#                     "name": "Quality Assurance"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "4cf77753-f2a1-40f6-a2ef-5bbb35cff413",
#                     "name": "Team Leadership"
#                 }
#             },
#             {
#                 "__typename": "Skill",
#                 "mustHave": true,
#                 "skill": {
#                     "__typename": "SkillDetail",
#                     "id": "b40ba574-80b9-40e1-8df4-ac6739543fd1",
#                     "name": "Microsoft Office"
#                 }
#             }
#         ],
#         "source": "NATIVE",
#         "status": "OPEN",
#         "title": "Apoteker Penanggung Jawab",
#         "traceInfo": "a89141604fd6fe6e52b59a3d3b526f07",
#         "type": "FULL_TIME",
#         "updatedAt": "2025-03-18T01:48:59.251000Z",
#         "workArrangementOption": "ONSITE"
#     }
# ]

# %%
import json
import csv
from pprint import pprint

# Load JSON with error handling
try:
    with open('glints700.json', 'r') as file:
        data = json.load(file)
except FileNotFoundError:
    print("Error: jobs.json file not found")
    exit(1)
except json.JSONDecodeError:
    print("Error: Invalid JSON format")
    exit(1)

# Safely extract jobs list
try:
    jobs = data['data']['searchJobs']['jobsInPage']
except KeyError:
    print("Error: Expected JSON structure not found")
    exit(1)

# Define fields
fields = ['city_name', 'industry_name', 'company_name', 'location_name', 'job_title']

# Extract data with error checking
job_list = []
for job in jobs:
    try:
        job_info = {
            'city_name': job['city']['name'],
            'industry_name': job['company']['industry']['name'],
            'company_name': job['company']['name'],
            'location_name': job['location']['formattedName'],
            'job_title': job['title']
        }
        job_list.append(job_info)
        # Optional: Print each job as it's processed
        pprint(job_info)
    except KeyError as e:
        print(f"Warning: Skipping job due to missing key: {e}")
        continue

# Write to CSV with error handling
try:
    with open('glints700_output.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fields)
        writer.writeheader()
        writer.writerows(job_list)
    print(f"Successfully wrote {len(job_list)} jobs to jobs_output.csv")
except IOError as e:
    print(f"Error writing CSV file: {e}")
# Out:
# {'city_name': 'Bogor',
#  'company_name': 'Kredivo Group',
#  'industry_name': 'Financial Services',
#  'job_title': 'Sales Promotor',
#  'location_name': 'Bogor Timur'}
# {'city_name': 'Tangerang Selatan',
#  'company_name': 'PT XC CLEANINDO',
#  'industry_name': 'Manufacturing',
#  'job_title': 'STAFF ACCOUNT RECEIVEBLE',
#  'location_name': 'Serpong'}
# {'city_name': 'Sidoarjo',
#  'company_name': 'PT Jago Rental',
#  'industry_name': 'Consumer Services',
#  'job_title': 'Mekanik Alat Berat',
#  'location_name': 'Krian'}
# {'city_name': 'Jakarta Selatan',
#  'company_name': 'PT. BLUE BIRD TBK | POOL PALMERAH',
#  'industry_name': 'Transportation/Trucking/Railroad',
#  'job_title': 'Sales Used Car',
#  'location_name': 'Kebayoran Lama'}
# {'city_name': 'Jakarta Barat',
#  'company_name': 'skmei smartwach',
#  'industry_name': 'Consumer Electronics',
#  'job_title': 'Translator Profesional',
#  'location_name': 'Cengkareng'}
# {'city_name': 'Bandung',
#  'company_name': 'PT. Bambu Cemerlang Ekspres',
#  'industry_name': 'Logistics and Supply Chain',
#  'job_title': 'Kurir Motor area Rancabali - Pasirjambu - Katapang',
#  'location_name': 'Ranca Bali'}
# {'city_name': 'Jakarta Utara',
#  'company_name': 'Bocorocco Shoes',
#  'industry_name': 'Retail',
#  'job_title': 'Creative Internship',
#  'location_name': 'Penjaringan'}
# {'city_name': 'Jakarta Pusat',
#  'company_name': 'PND Ice Machine',
#  'industry_name': 'Machinery',
#  'job_title': 'CEO Office',
#  'location_name': 'Gambir'}
# {'city_name': 'Malang',
#  'company_name': 'PT Persada Duta Beliton (Persada Indonesia Brand)',
#  'industry_name': 'Leisure, Travel & Tourism',
#  'job_title': 'Sales Executive (Cabang Malang & Gresik)',
#  'location_name': 'Lowokwaru'}
# {'city_name': 'Jakarta Barat',
#  'company_name': 'Nusantara Sakti Group',
#  'industry_name': 'Retail',
#  'job_title': 'General Manager Furniture',
#  'location_name': 'Grogol Petamburan'}
# {'city_name': 'Bekasi',
#  'company_name': 'PT Weebz Mandiri',
#  'industry_name': 'Oil & Energy',
#  'job_title': 'Marketing Intern (Magang)',
#  'location_name': 'Bekasi Utara'}
# {'city_name': 'Serang',
#  'company_name': 'JAVACO Indonesia',
#  'industry_name': 'Building Materials',
#  'job_title': 'PPIC Manager',
#  'location_name': 'Cikande'}
# {'city_name': 'Bekasi',
#  'company_name': 'Jakarta Event Enterprise',
#  'industry_name': 'Events Services',
#  'job_title': 'MARKETING SALES BALLROOM',
#  'location_name': 'Bekasi Selatan'}
# {'city_name': 'Malang',
#  'company_name': 'Sekawan Media',
#  'industry_name': 'Computer Software',
#  'job_title': 'Marketing',
#  'location_name': 'Singosari'}
# {'city_name': 'Sidoarjo',
#  'company_name': 'Java Residence',
#  'industry_name': 'Real Estate',
#  'job_title': 'surveyor infrastruktur',
#  'location_name': 'Sidoarjo'}
# {'city_name': 'Badung',
#  'company_name': 'King Trading',
#  'industry_name': 'Apparel & Fashion',
#  'job_title': 'Customer Liaison',
#  'location_name': 'Kuta Utara'}
# {'city_name': 'Kediri',
#  'company_name': 'segatama lestari pare',
#  'industry_name': 'Furniture',
#  'job_title': 'Digital marketing furniture',
#  'location_name': 'Pare'}
# {'city_name': 'Jember',
#  'company_name': 'PT Alam Lestari Unggul',
#  'industry_name': 'Construction',
#  'job_title': 'Sales Executive (KTP / Domisili Jember - Jawa Timur)',
#  'location_name': 'Sumbersari'}
# {'city_name': 'Sleman',
#  'company_name': 'PT Doodex Jaya Makmur',
#  'industry_name': 'Information Technology and Services',
#  'job_title': 'ODOO Developer',
#  'location_name': 'Kapanewon Ngaglik'}
# {'city_name': 'Bogor',
#  'company_name': 'CV. Kukche Mitra Sukses',
#  'industry_name': 'Education Management',
#  'job_title': 'English Tutor / Pengajar Bahasa Inggris - Bogor (Full Time)',
#  'location_name': 'Tanah Sareal'}
# {'city_name': 'Jakarta Utara',
#  'company_name': 'PT. Bintang Jaya Unggul Sentosa',
#  'industry_name': 'Primary/Secondary Education',
#  'job_title': 'Education Consultant',
#  'location_name': 'Penjaringan'}
# {'city_name': 'Jakarta Utara',
#  'company_name': 'Mul&Co Indonesia Tax Law Firm',
#  'industry_name': 'Law Practice',
#  'job_title': 'Tax Support',
#  'location_name': 'Penjaringan'}
# {'city_name': 'Jakarta Barat',
#  'company_name': 'TOKINDO.ID',
#  'industry_name': 'Retail',
#  'job_title': 'Sales Online Shop',
#  'location_name': 'Cengkareng'}
# {'city_name': 'Jakarta Barat',
#  'company_name': 'EF English First Jakarta ( Swara Group )',
#  'industry_name': 'Education Management',
#  'job_title': 'Customer Relation Officer (Sales) Jakarta Barat',
#  'location_name': 'Kebon Jeruk'}
# {'city_name': 'Pekanbaru',
#  'company_name': 'PT Astra International Tbk - Isuzu Sales Operation',
#  'industry_name': 'Automotive',
#  'job_title': 'Business Consultant Astra Isuzu',
#  'location_name': 'Pekanbaru Kota'}
# {'city_name': 'Medan',
#  'company_name': 'PT Astra International Tbk - Isuzu Sales Operation',
#  'industry_name': 'Automotive',
#  'job_title': 'Business Consultant Astra Isuzu',
#  'location_name': 'Medan Kota'}
# {'city_name': 'Badung',
#  'company_name': 'Glints',
#  'industry_name': 'Human Resources',
#  'job_title': 'Sales Intern - Bali',
#  'location_name': 'Kuta Utara'}
# {'city_name': 'Sleman',
#  'company_name': 'Causeway Culinary Group',
#  'industry_name': 'Food & Beverages',
#  'job_title': 'Crew Outlet & Crew Dapur',
#  'location_name': 'Kapanewon Ngaglik'}
# {'city_name': 'Sleman',
#  'company_name': 'PT Jaring Synergi Mandiri',
#  'industry_name': 'Outsourcing/Offshoring',
#  'job_title': 'Telesales Yogyakarta',
#  'location_name': 'Kapanewon Gamping'}
# {'city_name': 'Jakarta Barat',
#  'company_name': 'skmei smartwach',
#  'industry_name': 'Consumer Electronics',
#  'job_title': 'Host Live Streaming',
#  'location_name': 'Cengkareng'}
# {'city_name': 'Cimahi',
#  'company_name': 'PT Sinar Continental',
#  'industry_name': 'Textiles',
#  'job_title': 'Staff Accounting & Finance',
#  'location_name': 'Cimahi Selatan'}
# {'city_name': 'Surabaya',
#  'company_name': 'Manna Indo Lakta (MamaBear)',
#  'industry_name': 'Food Production',
#  'job_title': 'Apoteker Penanggung Jawab',
#  'location_name': 'Sambikerep'}
# {'city_name': 'Tangerang Selatan',
#  'company_name': 'PT LAXCEN WINTECH KALINGGA',
#  'industry_name': 'Electrical/Electronic Manufacturing',
#  'job_title': 'Sales Executive',
#  'location_name': 'Serpong'}
# {'city_name': 'Cimahi',
#  'company_name': 'PT Sinar Continental',
#  'industry_name': 'Textiles',
#  'job_title': 'Marketing Executive',
#  'location_name': 'Cimahi Selatan'}
# {'city_name': 'Cimahi',
#  'company_name': 'PT Sinar Continental',
#  'industry_name': 'Textiles',
#  'job_title': 'Marketing Follow Up',
#  'location_name': 'Cimahi Selatan'}
# {'city_name': 'Tangerang Selatan',
#  'company_name': 'PT LAXCEN WINTECH KALINGGA',
#  'industry_name': 'Electrical/Electronic Manufacturing',
#  'job_title': 'Production Supervisor',
#  'location_name': 'Serpong'}
# {'city_name': 'Bandung',
#  'company_name': 'WG Group Property',
#  'industry_name': 'Commercial Real Estate',
#  'job_title': 'Event & Collaboration Specialist',
#  'location_name': 'Regol'}
# {'city_name': 'Surabaya',
#  'company_name': 'Manulife Indonesia ( PT Asuransi Jiwa Manulife Indonesia )',
#  'industry_name': 'Insurance',
#  'job_title': 'Financial Specialist - Bancassurance - Surabaya',
#  'location_name': 'Wiyung'}
# {'city_name': 'Sambas',
#  'company_name': 'Manulife Indonesia ( PT Asuransi Jiwa Manulife Indonesia )',
#  'industry_name': 'Insurance',
#  'job_title': 'Sales Asuransi Bancassurance Pemangkat',
#  'location_name': 'Pemangkat'}
# {'city_name': 'Samarinda',
#  'company_name': 'Manulife Indonesia ( PT Asuransi Jiwa Manulife Indonesia )',
#  'industry_name': 'Insurance',
#  'job_title': 'Sales Asuransi Bancassurance Samarinda',
#  'location_name': 'Samarinda Ilir'}
# {'city_name': 'Banjarmasin',
#  'company_name': 'Manulife Indonesia ( PT Asuransi Jiwa Manulife Indonesia )',
#  'industry_name': 'Insurance',
#  'job_title': 'Sales Asuransi Bancassurance Banjarmasin',
#  'location_name': 'Banjarmasin Barat'}
# {'city_name': 'Tangerang Selatan',
#  'company_name': 'BUBUGAGA STORE',
#  'industry_name': 'Apparel & Fashion',
#  'job_title': 'Livestreamer',
#  'location_name': 'Pondok Aren'}
# {'city_name': 'Bandung',
#  'company_name': 'PT. TSMdR PT. Teknologi Solusi Mulai dari Ringan',
#  'industry_name': 'Consumer Electronics',
#  'job_title': 'Call Center Customer Center',
#  'location_name': 'Cibeunying Kaler'}
# {'city_name': 'Jakarta Pusat',
#  'company_name': 'Haluan Media Group',
#  'industry_name': 'Online Media',
#  'job_title': 'Business Development & Brand Partnerships',
#  'location_name': 'Tanah Abang'}
# {'city_name': 'Jakarta Pusat',
#  'company_name': 'Haluan Media Group',
#  'industry_name': 'Online Media',
#  'job_title': 'TikTok Social Media Specialist',
#  'location_name': 'Tanah Abang'}
# {'city_name': 'Jakarta Timur',
#  'company_name': 'PT.Bluebird Group',
#  'industry_name': 'Transportation/Trucking/Railroad',
#  'job_title': 'Driver',
#  'location_name': 'Ciracas'}
# {'city_name': 'Bandung',
#  'company_name': 'Upscale House Project',
#  'industry_name': 'Marketing and Advertising',
#  'job_title': 'Host Live Streaming Fashion',
#  'location_name': 'Batununggal'}
# {'city_name': 'Bandung',
#  'company_name': 'Upscale House Project',
#  'industry_name': 'Marketing and Advertising',
#  'job_title': 'Host Live Streaming Skincare',
#  'location_name': 'Batununggal'}
# {'city_name': 'Bekasi',
#  'company_name': 'Pt Mitra Sehat Indonesia',
#  'industry_name': 'Food & Beverages',
#  'job_title': 'Staff HR Generalist & Development',
#  'location_name': 'Bekasi Utara'}
# {'city_name': 'Bekasi',
#  'company_name': 'Kredivo Group',
#  'industry_name': 'Financial Services',
#  'job_title': 'Sales Promotor',
#  'location_name': 'Bekasi Selatan'}
# Successfully wrote 50 jobs to jobs_output.csv
